# %% [markdown]
# # Library importing

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl==0.15.2 triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf datasets huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

import pandas as pd
from datasets import Dataset

# %%
import re
import random
import json
from huggingface_hub import hf_hub_download, list_repo_files

# %% [markdown]
# # Building ambiguous questions

# %%
files = list_repo_files("LangAGI-Lab/pearl", repo_type="dataset")

train_file_path = hf_hub_download(
    repo_id="LangAGI-Lab/pearl",
    filename="train.json",
    repo_type="dataset"
)

validation_file_path = hf_hub_download(
    repo_id="LangAGI-Lab/pearl",
    filename="valid.json",
    repo_type="dataset"
)

test_file_path = hf_hub_download(
    repo_id="LangAGI-Lab/pearl",
    filename="test.json",
    repo_type="dataset"
)

trainDf = pd.read_json(train_file_path)
validationDf = pd.read_json(validation_file_path)
testDf = pd.read_json(test_file_path)

validation_ds = Dataset.from_pandas(validationDf)
test_ds       = Dataset.from_pandas(testDf)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# train.json:   0%|          | 0.00/198M [00:00<?, ?B/s]
# valid.json:   0%|          | 0.00/19.9M [00:00<?, ?B/s]
# test.json: 0.00B [00:00, ?B/s]

# %%
test_ds.features.keys()
# Out:
# dict_keys(['data_id', 'user_persona', 'seen_movie_titles', 'gt_abstract', 'gt_movie_title', 'gt_genre', 'gt_director', 'gt_cast', 'dialogue'])

# %%
N_SAMPLES = 200
OUT_PATH   = "ambiguous_200.json"

# We look for ambiguos words. (we manually chose these words)
AMBIG_PAT = re.compile(
    r"\b(any|something|maybe|whatever|similar|either|idk|recommend|like)\b",
    flags=re.I,
)

ACCEPT_PAT = re.compile(
    r"""(?xi)                       # verbose / ignore-case
    \b(
        thank(s| \s*you)                       |   # thanks
        sounds\s+(great|good|perfect|like)     |   # “sounds like …”
        perfect\s+fit                          |
        i('m| am)\s+sold                       |   # “I’m sold”
        i'?ll\s+               # future intent
            (
                (definitely\s+)?give\s+(it\s+a\s+)?(try|watch|look) |
                check\s+it\s+out |
                watch\s+it
            )                                   |
        can'?t\s+wait\s+to\s+watch
    )\b
    """)
GREETING_PAT = re.compile(r"hi there!?\s+i'?m in the mood", flags=re.I)
LIKE_TAG     = re.compile(r"\s*\[like\]\s*$", flags=re.I)

records = []

def collect_seeker_turns(example):
    dlg_id   = int(example.get("data_id", -1))
    dialogue = example["dialogue"]           # list[str]
    for idx, line in enumerate(dialogue):
        speaker, text = (line.split(":", 1) + [""])[:2]
        if not speaker.lower().strip().startswith("seeker"):
            continue

        # clean trailing “[Like]”
        clean_txt = LIKE_TAG.sub("", text).strip()

        records.append({
            "dialogue_id": dlg_id,
            "turn_id": idx,
            "context": dialogue[max(0, idx - 2):idx],
            "turn": clean_txt,
        })
    return example  # required return value

_ = validation_ds.map(collect_seeker_turns)
_ = test_ds.map(collect_seeker_turns)
print(f"Total seeker turns scanned: {len(records)}")

# Ambiguity filter
filtered, seen_turns = [], set()
greeting_kept = False

def is_ambiguous(txt: str) -> bool:
    return ("?" in txt) or bool(AMBIG_PAT.search(txt))

for rec in records:
    txt = rec["turn"]

    # drop explicit acceptance / closing lines
    if ACCEPT_PAT.search(txt):
        continue
    if not is_ambiguous(txt):
        continue

    # deduplicate identical turn text
    if txt in seen_turns:
        continue

    # allow only ONE generic greeting
    if GREETING_PAT.match(txt):
        if greeting_kept:
            continue
        greeting_kept = True

    seen_turns.add(txt)
    filtered.append(rec)

print(f"After cleaning & dedup: {len(filtered)} candidate turns")

# Sample exactly N_SAMPLES
if len(filtered) < N_SAMPLES:
    raise ValueError(f"Need {N_SAMPLES} examples but only {len(filtered)} left.")

random.shuffle(filtered)
ambig_200 = filtered[:N_SAMPLES]

with open(OUT_PATH, "w", encoding="utf-8") as fh:
    for obj in ambig_200:
        json.dump(obj, fh, ensure_ascii=False)
        fh.write("\n")

print(f"Saved {len(ambig_200)} rows to {OUT_PATH}")
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2277 [00:00<?, ? examples/s]
# Total seeker turns scanned: 37492
# After cleaning & dedup: 12187 candidate turns
# Saved 200 rows to ambiguous_200.json

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Print five random examples from ambiguous_200.json
"""
import json, random

with open("ambiguous_200.json", encoding="utf-8") as fh:
    rows = [json.loads(line) for line in fh]

random.seed(1)
for r in random.sample(rows, k=5):
    print("—" * 70)
    print(f"Dialogue {r['dialogue_id']} – turn {r['turn_id']}")
    if r["context"]:
        print("Context:")
        for c in r["context"]:
            print("   ", c)
    print("Seeker turn:")
    print("  ", r["turn"])
# Out:
# ——————————————————————————————————————————————————————————————————————
# Dialogue 39090 – turn 2
# Context:
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
# Seeker turn:
#    I'm looking for something with a dirty, grimey guilty pleasure feel. I also enjoy great acting performances.
# ——————————————————————————————————————————————————————————————————————
# Dialogue 13125 – turn 4
# Context:
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: What kind of movie are you in the mood for? Any specific genre or theme?
# Seeker turn:
#    I'm in the mood for something with a touch of fantasy and horror. I really enjoy movies with vivid filming, good performances, and realistic magic/special effects. Also, I like it when a movie captures a specific tradition well.
# ——————————————————————————————————————————————————————————————————————
# Dialogue 33965 – turn 4
# Context:
#     Seeker: I'm a big fan of movies that keep me on the edge of my seat with outstanding performances and a captivating storyline. I also love charming and heartwarming movies with fantastic performances and superior direction.", '
#     Recommender: How about watching "An American Tail" (1986)? It has heartwarming storytelling, great music, and well-cast characters that will surely captivate you.
# Seeker turn:
#    I appreciate the recommendation, but I feel like "An American Tail" (1986) may not have the same captivating performances and outstanding storyline that I'm looking for. I prefer movies with intense performances and engaging storyline. Can you recommend something else?
# ——————————————————————————————————————————————————————————————————————
# Dialogue 43431 – turn 10
# Context:
#     Seeker: I appreciate the recommendation, but "Run Fatboy Run" (2007) doesn't quite align with what I'm looking for. I'm more interested in movies that have a deeper psychological aspect and subtle strands that make it thought-provoking, as well as some good aerial footage. Do you have any other recommendations?
#     Recommender: How about "Youth in Revolt" (2010)? It has a unique and smart storyline, great aerial footage, and the main character's internal struggles add a psychological aspect to the comedy and romance elements. Plus, it's filled with hilarious situations and smart, funny dialogs. It might be exactly what you're looking for!
# Seeker turn:
#    I appreciate the recommendation, but "Youth in Revolt" (2010) doesn't quite fit my preferences. It seems to focus more on comedy and romance, and doesn't have the same subtle, psychological thriller aspects that I'm looking for. Any other suggestions?
# ——————————————————————————————————————————————————————————————————————
# Dialogue 53672 – turn 6
# Context:
#     Seeker: Hmm, "To Catch a Thief" sounds like a great movie, but I'm actually looking for something with a different feel. I'm really in the mood for a movie with constant movement of the camera, and characters that really stand out, especially a character like Elaine.
#     Recommender: How about watching "The Mummy" (1932)? It has a captivating storyline, intriguing characters, and a dreamy, atmospheric setting. The dynamic between the main characters is also very compelling, and it has a hint of an unlikely love story as well.
# Seeker turn:
#    Well, "The Mummy" (1932) seems like an interesting movie, but it's not really what I'm looking for right now. I'm hoping for something with a different kind of atmosphere and characters that I can really connect with.

# %% [markdown]
# # Clarification generator using Llama Instructor

# %% [markdown]
# Descargar de nuestro google drive ambiguous_200.json:

# %%
# !gdown 1GO2heE_J6ZA0M4L3DoVRDgiEXqigd9Qw
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GO2heE_J6ZA0M4L3DoVRDgiEXqigd9Qw
# To: /content/ambiguous_200.json
# 100% 152k/152k [00:00<00:00, 102MB/s]

# %% [markdown]
# You must use a huggingface account to use Meta's models.

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `Colab` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `Colab`

# %%
#!/usr/bin/env python3
import json, re, torch
from tqdm.auto import tqdm
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# ───── configuration ──────────────────────────────────────────────────
device           = "cuda" if torch.cuda.is_available() else "cpu"
ckpt_path        = "unsloth/llama-3-8b-Instruct-bnb-4bit"
batch_size       = 16
k_variants       = 4            # clarificaciones deseadas
max_attempts     = 5            # reintentos como máximo
temperature      = 0.8
top_p            = 0.95
top_k            = 50
rep_penalty      = 1.05
min_new_tokens   = 10
max_new_tokens   = 64
src_file         = "ambiguous_200.json"
dst_file         = "clarifications.json"

# ───── model & tokenizer ──────────────────────────────────────────────
bnb_cfg = BitsAndBytesConfig(load_in_4bit=True,
                              bnb_4bit_compute_dtype=torch.float16,
                              bnb_4bit_quant_type="nf4",
                              bnb_4bit_use_double_quant=True)
tok   = AutoTokenizer.from_pretrained(ckpt_path, padding_side="left")
model = AutoModelForCausalLM.from_pretrained(
            ckpt_path, quantization_config=bnb_cfg,
            device_map="auto").eval()

# ───── prompt prefix ─────────────────────────────────────────────────
system_prompt = (
    "You are Clarify-Bot.\n"
    "TASK: Rewrite ONLY the seeker's last message so it has ONE clear meaning.\n"
    "RULES:\n"
    "1. NO greetings, questions, pipes (|), or bullet lists.\n"
    "2. NO movie titles, years, or recommendations.\n"
    "3. Single sentence, 6-40 words.\n"
    "Return JUST the rewritten sentence."
)
prefix_ids = tok.apply_chat_template(
    [{"role": "system", "content": system_prompt}],
    tokenize=False, add_generation_prompt=False,
)
prefix_ids = tok(prefix_ids + tok.bos_token,
                 return_tensors="pt")["input_ids"][0]
assistant_tag_id = tok.convert_tokens_to_ids("<|assistant|>")

# ───── cleaners & filters (re-hechos) ─────────────────────────────────
LEADING_JUNK = re.compile(
    r'^\s*(assistant[:>\n]?|here\s+(is|are)\b[^:]*:|clarification:)', re.I)

QUOTE_TITLE   = re.compile(r'"[^"]+?"')          # "Title"  → elim.
YEAR_PAREN    = re.compile(r'\(\s*(19|20)\d{2}\s*\)')   # (1999)  etc.
ASSIST_TAIL   = re.compile(r'\bassistant\b.*$',  re.I)  # corta lo que siga
MULTI_SPACE   = re.compile(r'\s{2,}')            # colapsar espacios >1

BAD_PAT       = re.compile(
    r'(\|)|(^i\s+recommend)|\bthanks\b|\b(assistant|system)\b', re.I)

MIN_TOK, MAX_TOK = 6, 40     # después de limpiar
PUNCT_PREFIX = re.compile(r'^[\W_]+$')        # solo puntuación/guiones
URL_PREFIX   = re.compile(r'^\s*[:/\\]+')     # ://  ///  \\  etc.

def clean(text: str) -> str:
    text = LEADING_JUNK.sub('', text)
    text = ASSIST_TAIL.sub('', text)          # corta “assistant …”
    text = QUOTE_TITLE.sub('', text)          # quita «"Título"»
    text = YEAR_PAREN.sub('', text)           # quita (1999)
    text = URL_PREFIX.sub('', text)           # quita :// ó //
    text = MULTI_SPACE.sub(' ', text)
    return text.strip(" .\t\n")

def good(sent: str, original: str) -> bool:
    if not sent or PUNCT_PREFIX.fullmatch(sent):
        return False                          # sólo puntuación/residuo
    if BAD_PAT.search(sent):
        return False
    toks = sent.split()
    if not (MIN_TOK <= len(toks) <= MAX_TOK):
        return False
    return sent.lower() != original.lower()

def strip_assistant_artifacts(text: str) -> str:
    # Remove everything *before* the first ".assistant"
    first_assistant = text.find("assistant")
    if first_assistant != -1:
        text = text[first_assistant:]

    # Cut off everything after the second ".assistant"
    parts = text.split("assistant")
    if len(parts) > 2:
        text = ".assistant".join(parts[:2])

    # Remove all instances of '.assistant' and similar artifacts
    text = re.sub(r'\.?\s*assistant[:>\n]?', '', text, flags=re.I)

    return text.strip()


# ───── aclarar un turno hasta conseguir K válidas ─────────────────────
@torch.no_grad()
def clarify_one_turn(turn_text, k=k_variants, max_tries=max_attempts):
    collected, tries = [], 0
    while len(collected) < k and tries < max_tries:
        prompt_ids = torch.cat([
            prefix_ids,
            tok(turn_text + tok.eos_token + tok.bos_token,
                return_tensors="pt")["input_ids"][0],
        ]).unsqueeze(0).to(device)

        out = model.generate(
            input_ids            = prompt_ids,
            do_sample            = True,
            temperature          = temperature,
            top_p                = top_p,
            top_k                = top_k,
            repetition_penalty   = rep_penalty,
            min_new_tokens       = min_new_tokens,
            max_new_tokens       = max_new_tokens,
            num_return_sequences = 1,
            pad_token_id         = tok.eos_token_id,
            eos_token_id         = assistant_tag_id,
        )[0].cpu()

        # print(f"Tries {tries}")
        uncleaned_raw = tok.decode(out[prompt_ids.shape[1]:], skip_special_tokens=True)
        # print(f"uncleaned_raw: {uncleaned_raw}")
        uncleaned = strip_assistant_artifacts(uncleaned_raw)
        # print(f"uncleaned: {uncleaned}")
        candidate = clean(uncleaned)
        # print(f"Tries {tries}, cleaned: {candidate}")
        if good(candidate, turn_text) and candidate not in collected:
            collected.append(candidate)
        tries += 1

    if not collected:
        collected.append("Need a clearer one-sentence rewrite of the seeker’s request.")
    return collected

# ───── procesar el archivo ────────────────────────────────────────────
with open(src_file, encoding="utf-8") as fh:
    rows = [json.loads(l) for l in fh]

with open(dst_file, "w", encoding="utf-8") as fout:
    for i in tqdm(range(0, len(rows), batch_size), desc="Clarifying"):
        for rec in rows[i:i+batch_size]:
            rec["clarifications"] = clarify_one_turn(rec["turn"])
            json.dump(rec, fout, ensure_ascii=False); fout.write("\n")

print("Saved →", dst_file)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/quantizers/auto.py:222: UserWarning: You passed `quantization_config` or equivalent parameters to `from_pretrained` but the model you're loading already has a `quantization_config` attribute. The `quantization_config` from the model will be used.
#   warnings.warn(warning_msg)
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# Clarifying:   0%|          | 0/13 [00:00<?, ?it/s]
# Saved → clarifications.json

# %%
# show_samples.ipynb cell
import json, random, textwrap

FILE  = "clarifications.json"   # or ..._clean.json
N     = 200                                # how many examples to show

# ─── helper to read possibly-messy JSON-lines ─────────────────────────
def load_jsonl(path):
    rows, buf = [], ""
    with open(path, encoding="utf-8") as fh:
        for raw in fh:
            line = raw.strip()
            if not line:                 # skip empty lines
                continue
            try:
                rows.append(json.loads(line))
            except json.JSONDecodeError:
                # accumulate wrapped line fragments until they form JSON
                buf += line
                try:
                    rows.append(json.loads(buf))
                    buf = ""             # reset buffer
                except json.JSONDecodeError:
                    buf += " "           # keep accumulating
    if buf:                              # trailing fragment?
        try:
            rows.append(json.loads(buf))
        except json.JSONDecodeError:
            print("⚠️  trailing incomplete JSON ignored")
    return rows

rows = load_jsonl(FILE)
if N > len(rows):
    raise ValueError(f"File only has {len(rows)} lines (asked for {N})")

picked = random.sample(rows, k=N)

# ─── pretty-print ─────────────────────────────────────────────────────
for idx, row in enumerate(picked, 1):
    print("═" * 84)
    print(f"[{idx}] Dialogue {row['dialogue_id']} – turn {row['turn_id']}\n")

    if row.get("context"):
        print("Context (last 2 lines):")
        for c in row["context"][-2:]:
            print("   ", c)
        print()

    print("Seeker turn:")
    print(textwrap.fill("   " + row["turn"], width=80))
    print("\nClarifications:")
    for i, c in enumerate(row["clarifications"], 1):
        print(f"   {i}. {textwrap.fill(c, width=76, subsequent_indent=' '*6)}")
    print()
# Out:
# ════════════════════════════════════════════════════════════════════════════════════
# [1] Dialogue 33197 – turn 4
#
# Context (last 2 lines):
#     Seeker: I'm in the mood for a movie that has strong performances and a compelling storyline. I really appreciate a movie that has a talented cast and a well-executed plot.
#     Recommender: I think you would enjoy "The Last of Sheila" (1973) with its highly complex whodunit story and convincing performances. The ensemble cast and well-executed plot really make this movie stand out.
#
# Seeker turn:
#    I appreciate your recommendation, but I prefer movies with a darker sense of
# humor and ambiguous endings. I also enjoyed movies with a strong supporting
# cast, so maybe something along those lines would be more suitable for me.
#
# Clarifications:
#    1. I'd prefer movies with dark humor and open-ended conclusions, and those with
#       standout supporting performances might interest me
#    2. I prefer movies with darker humor and ambiguous endings, and a strong
#       supporting cast
#    3. You'd like to watch movies with dark humor and open-ended conclusions,
#       featuring a notable supporting cast
#    4. I prefer dark humor and ambiguous endings in movies, with a strong
#       supporting cast being an added bonus
#
# ════════════════════════════════════════════════════════════════════════════════════
# [2] Dialogue 43437 – turn 6
#
# Context (last 2 lines):
#     Seeker: Thank you for the recommendation, but I'm not really in the mood for a documentary right now. I was looking for something with a more dramatic narrative and strong acting performances. Do you have any other suggestions that fit that description?
#     Recommender: How about "Venus (2006)"? It features exceptional acting performances, a compelling storyline, and a portrayal of human emotions that you might find intriguing. Plus, it has a great blend of comedy and drama that I think you'd appreciate.
#
# Seeker turn:
#    I appreciate the recommendation, but "Venus" (2006) doesn't quite fit the
# bill for what I'm looking for. While it does have great acting performances and
# a compelling storyline, I'm not in the mood for a blend of comedy and drama at
# the moment. I'm more interested in a movie that focuses solely on drama with
# strong emotional depth. Any other suggestions that align more closely with that?
#
# Clarifications:
#    1. I'm seeking a drama movie with strong emotional depth, as comedy-dramas like
#       don't resonate with my current mood
#    2. I appreciate your suggestion, but Venus lacks the dramatic intensity and
#       emotional depth I'm currently seeking in a movie, so please suggest
#       something else that focuses solely on drama
#    3. I'd prefer a movie with a strong focus on drama, featuring powerful
#       emotional depth, rather than a mix of comedy and drama
#    4. I'd like a movie with a sole focus on drama, featuring strong emotional
#       depth, as comedy-drama blends don't currently appeal to me
#
# ════════════════════════════════════════════════════════════════════════════════════
# [3] Dialogue 4517 – turn 6
#
# Context (last 2 lines):
#     Seeker: Thank you for the recommendation, but I prefer movies with a bit more action and a historical or war-themed setting. I also like to see a portrayal of heroics and patriotism, which are common features in the movies I usually watch. Do you have any other suggestions based on that?
#     Recommender: How about "Dark Passage (1947)"? It's a film-noir thriller set in San Francisco in the 1940s and offers a different take on the genre. It has great style, strong performances from the cast, and a captivating story that I think you will enjoy.
#
# Seeker turn:
#    I appreciate the recommendation, but I'm really looking for something a bit
# more recent and with a war-themed setting. I also like movies with a focus on
# heroics and patriotism, which are common themes in the movies I usually watch.
# Do you have any other suggestions based on that?
#
# Clarifications:
#    1. I'm seeking a more recent war-themed movie with heroic and patriotic
#       elements, beyond what I've watched before
#    2. I'm seeking a more recent war-themed movie with a focus on heroism and
#       patriotism, similar to the ones I typically enjoy
#    3. I prefer more contemporary films set in war settings with heroic and
#       patriotic themes
#    4. Seeking a recent war-themed movie with heroic and patriotic elements,
#       focusing on heroism and national pride
#
# ════════════════════════════════════════════════════════════════════════════════════
# [4] Dialogue 25622 – turn 6
#
# Context (last 2 lines):
#     Seeker: Hmm, "Terminator Genisys" doesn't really fit what I'm looking for. I'm more into movies with great performances and a well-paced storytelling, like the ones with great representation of legends and excellent casting of actors.
#     Recommender: I think you'd enjoy "White House Down." It has great performances from Channing Tatum and Jamie Foxx, and the storytelling is well-paced with unexpected twists and turns. Plus, it's an action-packed thriller with plenty of suspense.
#
# Seeker turn:
#    I appreciate the recommendation, but "White House Down" doesn't quite match
# my preferences. I'm looking for a movie with great performances and a well-paced
# storytelling, like the ones with fun and fantastical adventures and cool scores
# that give off an epic adventure vibe.
#
# Clarifications:
#    1. I'm seeking a movie with outstanding performances, engaging narrative, and
#       exciting scores to create an epic adventure experience
#    2. I prefer movies with outstanding performances, well-crafted narratives, and
#       thrilling adventures accompanied by enchanting scores
#    3. I'm seeking a movie with outstanding performances, engaging narrative, and
#       an exciting atmosphere, preferably with thrilling quests and an
#       unforgettable soundtrack
#    4. I prefer movies with outstanding performances, engaging storytelling, and
#       captivating adventures featuring epic scores
#
# ════════════════════════════════════════════════════════════════════════════════════
# [5] Dialogue 10928 – turn 6
#
# Context (last 2 lines):
#     Seeker: Thanks for the recommendation, but I've actually watched "Dumbo" (2019) before. While I appreciate the heartfelt performances and the unique twist on the familiar tale, I found it lacking in Burton's trademark whimsy and the screenplay felt a bit lifeless and logic-free. I'm looking for something a bit different.
#     Recommender: How about "American Sniper" (2015)? It's a blend of drama and action, with a heartfelt performance from Bradley Cooper and a realistic portrayal of war and its impact. It offers a unique twist on the war genre and has strong storytelling.
#
# Seeker turn:
#    I appreciate the recommendation, but I've actually seen "American Sniper"
# (2015) before. While Bradley Cooper's performance was indeed heartfelt and the
# film had strong storytelling, I found the portrayal of the war and its politics
# to be oversimplified, and the screenplay felt a bit perfunctory. I'm looking for
# something a bit different.
#
# Clarifications:
#    1. I'm seeking a film that offers a more nuanced portrayal of war and its
#       complexities, differing from the simplistic representation in
#    2. I appreciated the movie, but its portrayal of war and politics seemed
#       oversimplified, and the screenplay felt a bit shallow
#    3. While I appreciated Bradley Cooper's performance in , I found the depiction
#       of war and its politics oversimplified and the screenplay somewhat
#       lacking depth
#    4. I appreciated the film's emotional depth, but found the depiction of war and
#       its complexities oversimplified and the screenplay lacking depth
#
# ════════════════════════════════════════════════════════════════════════════════════
# [6] Dialogue 46338 – turn 4
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I generally enjoy movies with strong performances, quirky comedy, and an
# ambitious storyline. Can you recommend something along those lines?
#
# Clarifications:
#    1. I relish films featuring exceptional acting, offbeat humor, and intriguing
#       narratives that challenge my expectations
#    2. I enjoy films with outstanding acting, offbeat humor, and complex narratives
#    3. I appreciate movies that feature outstanding acting, offbeat humor, and an
#       intriguing plot
#    4. I appreciate films featuring exceptional acting, offbeat humor, and a
#       captivating narrative
#
# ════════════════════════════════════════════════════════════════════════════════════
# [7] Dialogue 30457 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I'm in the mood for something with a unique and intriguing storyline. I also
# enjoy movies with well-developed characters and strong performances by the
# actors.
#
# Clarifications:
#    1. I'm drawn to stories with captivating narratives and nuanced portrayals of
#       characters brought to life by skilled actors
#    2. I crave stories with complex narratives and compelling characters, coupled
#       with outstanding acting performances
#    3. I crave a story with an unusual narrative and complex, well-acted characters
#    4. I crave narratives with distinctive plots and multi-dimensional characters
#       skillfully portrayed by talented actors
#
# ════════════════════════════════════════════════════════════════════════════════════
# [8] Dialogue 57564 – turn 4
#
# Context (last 2 lines):
#     Seeker: I'm a fan of movies with strong character performances, captivating visuals, and a good blend of comedy and drama. Any recommendations based on that?
#     Recommender: I think you would really enjoy "Paprika" (2006). It has amazing visuals, a captivating storyline, and a blend of comedy and drama that you might find intriguing. It's definitely worth watching!
#
# Seeker turn:
#    While "Paprika" (2006) sounds interesting, I prefer movies with a more
# realistic setting and a focus on everyday miracles and human kindness. I also
# enjoy movies with a blend of comedy, drama, and action. Do you have any other
# recommendations that fit these criteria?
#
# Clarifications:
#    1. I crave films that combine relatable settings, everyday miracles, human
#       kindness, and a mix of comedy, drama, and action
#    2. I enjoy movies that balance realism with uplifting themes, blending humor,
#       drama, and action to explore everyday miracles and human connection
#    3. I seek movies with realistic settings and everyday miracles showcasing human
#       kindness, blending comedy, drama, and action
#    4. I'm drawn to stories about ordinary people experiencing extraordinary
#       moments of human connection, set in relatable settings, blending
#       humor, emotion, and action
#
# ════════════════════════════════════════════════════════════════════════════════════
# [9] Dialogue 701 – turn 6
#
# Context (last 2 lines):
#     Seeker: I'm looking for something fast and easy to view, a good way to spend my time. Perhaps something with action or comedy would be great!
#     Recommender: How about watching "In the Name of the Father"? It's a gripping biography and crime drama with powerful performances and an emotional impact that would definitely keep you engaged.
#
# Seeker turn:
#    Hmm, "In the Name of the Father" sounds interesting, but I'm actually looking
# for something a bit lighter and more entertaining. I tend to enjoy movies that
# are fast-paced and have a good mix of action and comedy.
#
# Clarifications:
#    1. I'm seeking a movie that balances action and humor, offering a light-hearted
#       entertainment experience
#    2. I'm seeking a lighthearted film with a balance of action and humor,
#       preferably featuring adventurous storytelling
#    3. I'm seeking light-hearted, fast-paced movies with a balance of action and
#       humor
#    4. I'm seeking a lighthearted, fast-paced movie with equal parts action and
#       comedy
#
# ════════════════════════════════════════════════════════════════════════════════════
# [10] Dialogue 57611 – turn 6
#
# Context (last 2 lines):
#     Seeker: Thanks for the recommendation, but I'm not really a fan of "Only God Forgives". I usually prefer movies with a more magical storytelling that creates a sense of wonder, and the score is a huge factor for me. Do you have something else in mind that fits that description?
#     Recommender: How about "Field of Dreams"? It's a heartwarming film with a magical and wonderous storytelling, and the score really adds to the emotional impact of the movie. I think you'll enjoy the sense of wonder and magic that it creates.
#
# Seeker turn:
#    Hmm, "Field of Dreams" sounds nice, but I've already seen it before and I'm
# looking for something new. I really appreciate the recommendation, but do you
# have something else in mind that fits my preferences?
#
# Clarifications:
#    1. I'm seeking a fresh movie suggestion that I haven't seen before, as I've
#       already watched Field of Dreams
#    2. I'm seeking a different film to watch that captures a similar essence to
#       without being the same movie
#    3. I'd like a movie recommendation that's different from what I've seen before,
#       as I've already watched and am seeking something new
#    4. I'm seeking a movie with a unique storyline that's not as well-known as
#
# ════════════════════════════════════════════════════════════════════════════════════
# [11] Dialogue 4554 – turn 6
#
# Context (last 2 lines):
#     Seeker: Hmmm, I'm not sure *batteries not included is exactly what I'm in the mood for. I'm more into movies with a bit more slapstick humor and a performance that's a bit more over the top. Do you have anything else in mind that fits that description?
#     Recommender: How about The Dead Pool? It has a lot of action and suspense, with an over-the-top performance by Clint Eastwood. The car chase scene is rather unusual and entertaining, and it has a great opening theme. Plus, it features the feature film debut of Jim Carrey, so you can expect some good humor in there as well.
#
# Seeker turn:
#    I appreciate the recommendation, but I think The Dead Pool doesn't quite fit
# the bill for what I'm looking for. I'm more in the mood for a comedy with a
# strong visual and spoken humor, as well as a good soundtrack. Do you have
# anything else in mind that matches those qualities?
#
# Clarifications:
#    1. I'm looking for a comedy with strong visuals, spoken humor, and a good
#       soundtrack
#    2. I prefer a comedy with a strong visual and spoken humor, accompanied by a
#       catchy soundtrack
#    3. I'm seeking a comedy with a strong visual and spoken humor, along with a
#       great soundtrack
#    4. I'm seeking a comedy film with both strong visual and spoken humor,
#       accompanied by a notable soundtrack
#
# ════════════════════════════════════════════════════════════════════════════════════
# [12] Dialogue 72692 – turn 6
#
# Context (last 2 lines):
#     Seeker: I appreciate the recommendation, but I've actually seen "Lady Bird" before. While I did like the characters and the darker themes explored, I found the story to be a bit unoriginal. Do you have any other recommendations that fit my preferences?
#     Recommender: How about "Hitchcock" (2012)? It's a biography-drama with a touch of romance and has genuinely funny moments, odd but charming characters, and a unique approach to the story of the making of Psycho. The performances are outstanding, and it definitely has darker themes explored in a unique way. I think you'd enjoy it!
#
# Seeker turn:
#    I appreciate the recommendation, but I've actually seen "Hitchcock" before.
# While I did enjoy the excellent acting and the interesting glimpse into the mind
# of Alfred Hitchcock, I found the pacing to be a bit rushed. Do you have any
# other recommendations that fit my preferences?
#
# Clarifications:
#    1. I enjoyed the acting and insight into Hitchcock's mind, but the film's
#       pacing felt rushed, leading me to seek alternative recommendations
#       that better match my preferences
#    2. I enjoyed the acting and gained insight into Hitchcock's mind, but I felt
#       the pace was too fast; can you suggest other movies that fit my taste?
#    3. I found the acting and insights into Hitchcock's mind engaging, but the
#       pacing felt hurried, leading me to seek alternative film
#       recommendations
#    4. I've seen the film and while I enjoyed the acting and insight into the
#       director's mind, the pacing felt rushed
#
# ════════════════════════════════════════════════════════════════════════════════════
# [13] Dialogue 21274 – turn 6
#
# Context (last 2 lines):
#     Seeker: Hmm, I've watched "We Own the Night" before and it wasn't really my cup of tea. I generally prefer movies with genuine plots and realist twists. Plus, I appreciate strong performances from the entire cast. Any other recommendations that fit that bill?
#     Recommender: I'd recommend "Dunkirk." It's a gripping war drama that tells the story from three perspectives non-chronologically, with intense events happening on screen. The lack of lead characters and character depth allows the audience to care for each and every one of the men on the beach, and the performances are incredibly strong across the board.
#
# Seeker turn:
#    I actually prefer crime and thriller movies, so "Dunkirk" doesn't quite fit
# my preferences. I like when the plot has a realist twist and the movie keeps the
# viewer asking questions in a classic way. Any other recommendations in that
# genre?
#
# Clarifications:
#    1. I enjoy thrillers with realistic plots that maintain suspense through clever
#       twists and keep viewers engaged in classic, thought-provoking
#       storytelling
#    2. I prefer crime and thriller movies with realistic twists that keep viewers
#       engaged, seeking answers
#    3. I enjoy crime and thrillers with realistic twists, keeping viewers engaged
#       by raising questions and maintaining suspense in a classical manner
#    4. I'd suggest you try films with complex, suspenseful plots that keep you
#       guessing until the end, such as those from Alfred Hitchcock
#
# ════════════════════════════════════════════════════════════════════════════════════
# [14] Dialogue 16567 – turn 6
#
# Context (last 2 lines):
#     Seeker: I generally enjoy movies with well-developed characters and a smooth storyline. I also appreciate good visual effects and realistic performances from the cast. Any recommendations based on that?
#     Recommender: I think you would really enjoy "Tremors (1990)." It has well-developed characters, a smooth storyline, great visual effects for its time, and the cast delivers realistic performances. Plus, it's a good old-fashioned monster movie with a mix of comedy and horror that I think you'll appreciate.
#
# Seeker turn:
#    I appreciate the recommendation, but I think I'll have to pass on "Tremors
# (1990)." While it does have some of the features I enjoy, I'm not really in the
# mood for a monster movie with a mix of comedy and horror. Do you have any other
# recommendations that fit my preferences better?
#
# Clarifications:
#    1. I'd like to watch a movie with a blend of genres, specifically something
#       that balances humor and suspense
#    2. I'd prefer a different movie with a blend of genres, something more serious
#       and less reliant on comedy and horror
#    3. I'm not interested in a monster movie with comedic elements and horror,
#       seeking alternative suggestions that fit my preferences
#    4. I'm looking for a different movie, preferably without monsters, comedy, and
#       horror, with features that match my preferences
#
# ════════════════════════════════════════════════════════════════════════════════════
# [15] Dialogue 26765 – turn 6
#
# Context (last 2 lines):
#     Seeker: Thank you for the recommendation, but "Double Indemnity" doesn't quite match the features I enjoy in movies. I tend to be drawn to movies with vivid slang and spirited performances by the actors. Do you have any other recommendations that align with those preferences?
#     Recommender: How about giving "Follow the Fleet" a try? It's a classic musical comedy with outstanding music, spirited performances by Fred Astaire and Ginger Rogers, and a mix of heartwarming and comical moments that I think you'll really appreciate.
#
# Seeker turn:
#    Unfortunately, "Follow the Fleet" doesn't quite match my preferences either.
# I'm more into movies with beautifully filmed scenes, stunning costumes, and
# witty banter between the characters. Do you have any other recommendations that
# fit those criteria?
#
# Clarifications:
#    1. I prefer movies with captivating visuals, elegant attire, and clever
#       dialogue between characters
#    2. I'm seeking movies with breathtaking visuals, exquisite costumes, and
#       engaging dialogue among characters
#    3. I prefer movies with beautifully filmed scenes, stunning costumes, and witty
#       dialogue between characters
#    4. I'm seeking movies with visually stunning scenes, intricate costumes, and
#       engaging dialogue exchanges
#
# ════════════════════════════════════════════════════════════════════════════════════
# [16] Dialogue 4433 – turn 8
#
# Context (last 2 lines):
#     Seeker: I'm sorry, but "The Magnificent Seven" doesn't quite fit what I'm looking for. The movie I have in mind has a comedy-drama mix with a unique concept and strong performances. It's not quite an adventure film. Any other recommendations?
#     Recommender: Based on your preference for a unique concept, strong performances, and a mix of comedy and drama, I recommend "Ready Player One" (2018). It incorporates action, adventure, and sci-fi elements while also providing a solid plot and delivery. The imaginative cinematography and pop culture references add to the entertainment value of the film. I think you'll enjoy the blend of comedy, drama, and adventure in this movie.
#
# Seeker turn:
#    I understand why you'd recommend "Ready Player One," but I'm looking for
# something with a more grounded mix of comedy and drama. The film I have in mind
# has a good balance of awkwardness, drama, and entertainment value with strong
# performances. It's not quite an action-adventure film. Any other suggestions
# that fit that description?
#
# Clarifications:
#    1. The film I'm thinking of has a well-balanced blend of awkwardness, drama,
#       and entertainment value, featuring strong performances without being
#       an action-adventure film
#    2. I'm seeking a film with a well-balanced blend of comedy, drama, and strong
#       performances, featuring awkward moments, without being an action-
#       adventure
#    3. I'm seeking a film with a balanced mix of awkwardness, drama, and
#       entertainment value, featuring strong performances and lacking action-
#       adventure elements
#    4. You're seeking a film that strikes a balance between comedy and drama,
#       featuring strong performances and awkward moments, without being an
#       action-adventure film
#
# ════════════════════════════════════════════════════════════════════════════════════
# [17] Dialogue 33965 – turn 4
#
# Context (last 2 lines):
#     Seeker: I'm a big fan of movies that keep me on the edge of my seat with outstanding performances and a captivating storyline. I also love charming and heartwarming movies with fantastic performances and superior direction.", '
#     Recommender: How about watching "An American Tail" (1986)? It has heartwarming storytelling, great music, and well-cast characters that will surely captivate you.
#
# Seeker turn:
#    I appreciate the recommendation, but I feel like "An American Tail" (1986)
# may not have the same captivating performances and outstanding storyline that
# I'm looking for. I prefer movies with intense performances and engaging
# storyline. Can you recommend something else?
#
# Clarifications:
#    1. I appreciate the recommendation, but I prefer films with intense
#       performances and engaging storylines
#    2. I'm looking for a movie with intense performances and an engaging storyline,
#       different genres considered
#    3. A film with intense performances and an engaging storyline should provide a
#       more impactful viewing experience, unlike
#    4. I'd prefer a film with captivating performances and an engaging storyline,
#       prioritizing intensity over nostalgic value
#
# ════════════════════════════════════════════════════════════════════════════════════
# [18] Dialogue 50934 – turn 6
#
# Context (last 2 lines):
#     Seeker: That sounds interesting, but I'm not really in the mood for a teen comedy right now. I'm looking for something with a more dramatic and intense storyline, and I'm not a big fan of teen comedies in general. Is there anything else you could recommend?
#     Recommender: How about "Accidents Happen" (2010)? It has a dramatic and intense storyline with memorable moments and excellent performances, especially from Geena Davis. The film also explores the mother/son relationship and has some terrific slow-motion scenes that add to the overall impact of the story.
#
# Seeker turn:
#    I appreciate the recommendation, but I don't think "Accidents Happen" is
# quite what I'm looking for. I'm really looking for something with a more complex
# and realistic portrayal of characters. Do you have any other recommendations
# that fit that description?
#
# Clarifications:
#    1. I'm seeking a story with complex characters and realistic portrayal
#    2. I'm seeking a story with complex characters, not just an accident-prone plot
#    3. I'm seeking a more nuanced representation of characters in a story, rather
#       than a lighthearted take on accidents
#    4. I've rephrased the seeker's message to convey a single clear meaning: I'd
#       like a story with complex, realistic characters, not just a
#       lighthearted take on accidents
#
# ════════════════════════════════════════════════════════════════════════════════════
# [19] Dialogue 51501 – turn 8
#
# Context (last 2 lines):
#     Seeker: "Children Shouldn't Play with Dead Things" sounds intriguing, but I'm looking for a movie with a more serious tone and deeper exploration of existential concepts, similar to the movie "Millennium." I appreciate the recommendation though.
#     Recommender: I think you might enjoy "On the Beach" (1959). It has a deep and thought-provoking exploration of the impact of choices, with a complex storyline that will definitely have you contemplating about life and the future. The exceptional cast and brilliant directing add to the emotional impact and powerful performances.
#
# Seeker turn:
#    "On the Beach" (1959) does sound intriguing, but I'm looking for a movie with
# a darker and more intense portrayal of the impact of choices, similar to the
# movie "Millennium." I appreciate the recommendation though.
#
# Clarifications:
#    1. I'm seeking a darker, more intense film that explores the consequences of
#       choices, similar to , as the beach setting in doesn't convey the same
#       level of intensity
#    2. I seek a movie that portrays the darker consequences of choices in a more
#       intense manner, similar to
#    3. I'm seeking a film that explores the consequences of choices in a dark and
#       intense manner, similar to
#    4. I seek a movie that presents a darker and more intense exploration of the
#       consequences of choices, similar to , showcasing the devastating
#       outcomes of decisions made
#
# ════════════════════════════════════════════════════════════════════════════════════
# [20] Dialogue 3757 – turn 8
#
# Context (last 2 lines):
#     Seeker: I can see how "Firehouse Dog (2007)" fits some of my criteria, but I think I lean more towards movies with a different kind of intense and involvement, devastating use of music, and searing cinematography. Any recommendations based on those features?
#     Recommender: How about watching "The Secret Life of Bees (2008)"? It has intense and involvement, a devastating use of music, and searing cinematography. The strong performances and engaging story will definitely captivate you.
#
# Seeker turn:
#    "The Secret Life of Bees (2008)" sounds intriguing, but I think I'm more
# drawn towards movies with a comprehensive update from a different time period,
# perfect casting, and a reeking atmosphere. Do you have any recommendations that
# fit those features?
#
# Clarifications:
#    1. I'm more drawn to movies with a comprehensive update from a different time
#       period, perfect casting, and a strong atmospheric setting
#    2. I'm drawn to movies with a comprehensive update from a different time
#       period, perfect casting, and an eerie atmosphere, preferably featuring
#       influential literary figures
#    3. I'm looking for a movie with a captivating storyline, accurate historical
#       setting, excellent casting, and an immersive atmosphere that would
#       distract me from my concerns
#    4. I'm intrigued by movies with a comprehensive update from a different time
#       period, perfect casting, and a strong atmosphere, so please recommend
#       recent films with these features
#
# ════════════════════════════════════════════════════════════════════════════════════
# [21] Dialogue 26059 – turn 4
#
# Context (last 2 lines):
#     Seeker: I'm looking for a movie with a strong performance from the cast and a thought-provoking storyline. I enjoy movies with a battle between right and wrong, ethical and unethical dilemmas.
#     Recommender: How about Zoolander? It has a great cast and deals with ethical dilemmas in a satirical way. Plus, it has a lot of absurd humor which you might enjoy.
#
# Seeker turn:
#    I appreciate the recommendation, but I'm not a big fan of satirical comedies.
# I prefer movies with a more serious tone and a deeper exploration of ethical
# dilemmas. Some of the movies I've enjoyed in the past have had a well-conceived
# script and outstanding cast, with breathtaking visual effects. Can you think of
# anything that fits that description?
#
# Clarifications:
#    1. I'm seeking a movie with a serious tone, well-written script, outstanding
#       cast, and impressive visual effects, focusing on exploring complex
#       moral issues
#    2. I'd like to know if you can suggest movies that balance serious tone and
#       strong casts with thought-provoking ethical explorations, featuring
#       well-crafted scripts and stunning visuals
#    3. I appreciate serious movies that explore ethical dilemmas with well-crafted
#       scripts, outstanding casts, and stunning visuals
#    4. I prefer films with a serious tone, exploring ethical dilemmas, featuring
#       well-written scripts, outstanding casts, and impressive visuals
#
# ════════════════════════════════════════════════════════════════════════════════════
# [22] Dialogue 31887 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I'm in the mood for something with a strong performance and exploration of
# meaningful themes, like superstition, faith, and hope. Usually, I enjoy movies
# that have a simple plot and relatable storyline, with some enjoyable and witty
# dialogue.
#
# Clarifications:
#    1. I'm seeking a film with a strong performance, exploring themes of
#       superstition, faith, and hope, with a simple plot and relatable
#       characters
#    2. I seek a film with a powerful performance, exploring themes of superstition,
#       faith, and hope, featuring a straightforward narrative and relatable
#       characters with clever dialogue
#    3. I'm drawn to stories with powerful performances that explore profound themes
#       like superstition, faith, and hope through simple yet relatable
#       narratives
#    4. I seek a film with a powerful performance, exploring themes of superstition,
#       faith, and hope, and featuring a straightforward narrative, relatable
#       characters, and engaging dialogue
#
# ════════════════════════════════════════════════════════════════════════════════════
# [23] Dialogue 34964 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I'm in the mood for a movie with a great storyline, strong performances from
# the cast, and maybe some thrilling moments. Can you recommend something like
# that?
#
# Clarifications:
#    1. I'm craving a film with a captivating plot, exceptional acting, and
#       suspenseful scenes
#    2. I'm seeking a movie with a compelling narrative, exceptional acting, and
#       suspenseful scenes
#    3. A movie with a compelling narrative, outstanding acting, and suspenseful
#       scenes would be enjoyable
#    4. I'm looking for a movie with a captivating plot, impressive acting, and
#       suspenseful scenes
#
# ════════════════════════════════════════════════════════════════════════════════════
# [24] Dialogue 7052 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I'm looking for a movie with great acting and a compelling storyline. I also
# enjoy emotional scenes and heartbreaking endings. Any recommendations based on
# that?
#
# Clarifications:
#    1. A movie with outstanding performances, a captivating narrative, and poignant
#       conclusions is what you're seeking
#    2. A movie with exceptional acting, emotional scenes, and a poignant conclusion
#       is what I'm seeking, with a preference for dramatic storytelling
#    3. I seek a movie with remarkable acting, captivating plot, and poignant
#       moments, including tear-jerking conclusions
#    4. A movie with outstanding performances, a captivating narrative, and poignant
#       moments of emotional intensity culminating in a memorable, heart-
#       wrenching conclusion
#
# ════════════════════════════════════════════════════════════════════════════════════
# [25] Dialogue 36585 – turn 4
#
# Context (last 2 lines):
#     Seeker: I prefer movies that rely on storytelling over special effects and minimal horror effects that are still effective.
#     Recommender: Based on your preferences, I think you would really enjoy "Before Sunset" (2004). It's a drama with a strong focus on storytelling, and the romantic element is minimal but effective. The dialogue and acting are both fantastic, and it really draws you in with its emotional depth and intensity.
#
# Seeker turn:
#    "Before Sunset" sounds interesting, but I'm looking for something with a
# different kind of vibe right now. I really enjoy movies with great performances
# and attention to detail in the direction. The use of colors and an unpredictable
# twist are also some elements I appreciate in a movie. Do you have any
# recommendations based on these features?
#
# Clarifications:
#    1. I'm seeking a film with outstanding performances, meticulous direction,
#       vivid colors, and an unexpected plot turn, if you know of such a movie
#    2. I'm drawn to films with exceptional acting, meticulous direction, vivid
#       visuals, and unexpected plot turns, seeking something new that
#       captures my attention
#    3. I crave films with outstanding performances, meticulous direction, striking
#       colors, and unexpected plot turns
#    4. I'm seeking a movie that offers unique color schemes, captivating
#       performances, and unexpected plot twists, rather than which seems too
#       conventional
#
# ════════════════════════════════════════════════════════════════════════════════════
# [26] Dialogue 57406 – turn 6
#
# Context (last 2 lines):
#     Seeker: "Secret Window" sounds interesting, but I'm looking for something with a more space-tripping, mind-blowing adventure feel, like the Star Trek series. I want a movie that provides an in-depth look at a specific topic, while also being enjoyable for both fans and newcomers to the genre.
#     Recommender: I'd recommend "The Matrix" (1999). It provides an immersive and thought-provoking experience, with a unique take on the dystopian future and advanced technology. The storyline and action sequences are truly mind-blowing, and the performances by the cast are top-notch.
#
# Seeker turn:
#    "The Matrix" is a great recommendation, but I'm actually in the mood for a
# drama, mystery, or thriller. Do you have any movies in mind that fit that
# description?
#
# Clarifications:
#    1. I'm looking for a drama, mystery, or thriller movie recommendation
#    2. I'm seeking a dramatic, mysterious, or thrilling movie recommendation
#    3. I'd like to watch a drama, mystery, or thriller movie instead of sci-fi
#    4. I seek a drama, mystery, or thriller movie that fits my current mood
#
# ════════════════════════════════════════════════════════════════════════════════════
# [27] Dialogue 63259 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I'm not a big fan of long, pointless, and boring movies. I prefer something
# that's coherent and not confusing. I also enjoy movies that provide a serious
# wake-up call about certain aspects of life. Any recommendations based on that?
#
# Clarifications:
#    1. I prefer movies that are concise and coherent, with meaningful messages that
#       challenge my perspective on life
#    2. I prefer movies with coherent storytelling and thought-provoking themes that
#       challenge my perspective on life
#    3. I'm drawn to thought-provoking movies with coherent storytelling that offer
#       a serious reflection on life, providing a meaningful experience rather
#       than mere entertainment
#    4. I prefer movies that are concise and engaging, with thought-provoking themes
#       that raise awareness about important issues
#
# ════════════════════════════════════════════════════════════════════════════════════
# [28] Dialogue 14315 – turn 6
#
# Context (last 2 lines):
#     Seeker: Thanks for the recommendation, but I'm not a fan of animated movies. I prefer movies with a realistic feel, character development, and compelling storytelling. Do you have any other recommendations that align with those features?
#     Recommender: Based on your preference for realistic feel, character development, and compelling storytelling, as well as strong ensemble cast and outstanding performances, I recommend "Dunkirk (2017)." It has a gripping narrative, outstanding performances, and a realistic portrayal of historical events.
#
# Seeker turn:
#    I appreciate the suggestion, but I've already seen "Dunkirk (2017)." While it
# does have some strong elements, I prefer movies with a more lively and
# entertaining feel, with a great soundtrack that evokes nostalgia. Do you have
# any other recommendations that align with those features?
#
# Clarifications:
#    1. I'm looking for a movie with a lively and entertaining feel, a great
#       soundtrack, and nostalgic value
#    2. I'm looking for a movie with a lively atmosphere, an engaging soundtrack,
#       and nostalgic value
#    3. I seek a film with a lively tone, engaging story, and nostalgic soundtrack
#    4. I'd like to know if you have any movie suggestions that combine engaging
#       storytelling with an upbeat tone and memorable music that conjures a
#       sense of nostalgia
#
# ════════════════════════════════════════════════════════════════════════════════════
# [29] Dialogue 53375 – turn 6
#
# Context (last 2 lines):
#     Seeker: It sounds like a great movie, but I don't think it quite fits my preferences. I'm more into movies with animation and a sense of adventure. The exploration of characters' backgrounds and the voice acting are important to me. Do you have any recommendations based on that?
#     Recommender: I think you would enjoy "Open Water." It's an adventure film with a strong focus on character exploration and intense, gripping storytelling. The use of water as a backdrop and the performances of the two lead actors really bring out the sense of adventure and survival in the movie.
#
# Seeker turn:
#    "Open Water" sounds intriguing, but I'm not really into movies that falter in
# their creativity and engagement. I appreciate the recommendation, but I think
# I'm looking for something a bit different. Any other recommendations based on
# what I've mentioned before?
#
# Clarifications:
#    1. The recommendation didn't resonate with me, as I prefer more creative and
#       engaging content
#    2. I'm not interested in movies that lack creativity and engagement, suggesting
#       I'd prefer something more unique and captivating
#    3. I'd like unique and engaging entertainment, not something predictable or
#       unoriginal, can you suggest something better fitting my tastes?
#    4. I'm seeking something more engaging than the usual formulaic storytelling,
#       with a unique premise and attention-grabbing plot
#
# ════════════════════════════════════════════════════════════════════════════════════
# [30] Dialogue 39562 – turn 6
#
# Context (last 2 lines):
#     Seeker: Thank you for the recommendation, but I think I'll pass on "A Bad Moms Christmas". While it may have some hilarious and sweet moments, I'm really looking for a movie with flawed and realistic characters, and I don't think this movie quite fits that criteria. Do you have any other recommendations?
#     Recommender: How about "The Last King of Scotland" (2006)? It features flawed and realistic characters, with a mix of hilarious, dark, and sweet moments. Plus, the performances by Forest Whitaker and James McAvoy are exceptional, and the movie has a realistic atmosphere and setting in Uganda in the 1970s. It's a character-driven drama with beautiful cinematography that you might enjoy!
#
# Seeker turn:
#    "The Last King of Scotland" sounds interesting, but I think I'll have to pass
# on that one as well. I'm really looking for a movie that also has great
# character development, and while this movie seems to have flawed and realistic
# characters, I'm not sure if it has the character development I'm looking for. Do
# you have any other recommendations?
#
# Clarifications:
#    1. I'm seeking a movie with great character development, focusing on flawed and
#       realistic characters
#    2. I seek a movie with both engaging storyline and well-developed characters
#    3. I'm seeking a movie with great character development, featuring flawed and
#       realistic characters, but without relying heavily on plot similarities
#       to
#    4. I'm seeking a movie with strong character development, as appears to have
#       realistic flaws but may lack depth in its characters
#
# ════════════════════════════════════════════════════════════════════════════════════
# [31] Dialogue 31115 – turn 8
#
# Context (last 2 lines):
#     Seeker: I've actually seen "Zootopia" before, and while I enjoyed some aspects of it like the music and some of the characters, I found the story a bit predictable and not as entertaining as I had hoped. I'm really looking for something with a bit more depth and edge to it. Do you have any other recommendations in mind?
#     Recommender: Have you considered watching "Lost in Translation" (2003)? It has strong performances from Bill Murray and Scarlett Johansson, and it's known for its unique visual aesthetics and realistic feel. The relationship development between the characters might resonate with you, and it's a mix of comedy and drama with depth and edge in its storytelling.
#
# Seeker turn:
#    "Lost in Translation" is a great movie, but I have already seen it. It does
# have some aspects that I enjoy, like the unique visual aesthetics and strong
# performances, but I'm really in the mood for something a bit more action-packed
# and visually stunning. Do you have any other recommendations that fit that
# description?
#
# Clarifications:
#    1. I'm seeking a movie with visually stunning and action-packed content,
#       featuring talented actors
#    2. I've seen and enjoyed its visuals and performances, but now I'm craving an
#       action-packed film with impressive visuals
#    3. I'm seeking a film with unique visuals and strong performances, but also
#       fast-paced action and stunning visuals
#    4. I'm seeking an action-packed film with striking visuals, beyond , which I've
#       already seen and enjoyed its unique style and acting
#
# ════════════════════════════════════════════════════════════════════════════════════
# [32] Dialogue 29116 – turn 6
#
# Context (last 2 lines):
#     Seeker: "Corpse Bride" sounds interesting, but I'm looking for something with more realistic and gripping performances. Do you have any recommendations that really showcase the acting talent of the cast?
#     Recommender: I think you would really enjoy "The Muppet Christmas Carol." It has wonderful performances, particularly from Michael Caine as Scrooge. The chemistry between him and the Muppets is fantastic, and the emotional depth of the story really shines through in the actors' performances.
#
# Seeker turn:
#    "The Muppet Christmas Carol" is definitely a great movie, but I'm actually
# looking for something a bit more serious and dramatic. Do you have anything
# along those lines that you could recommend?
#
# Clarifications:
#    1. I seek recommendations for serious and dramatic stories with ongoing
#       storylines and complex characters
#    2. I'm seeking a serious and dramatic film to watch instead of
#    3. I seek a serious and dramatic movie recommendation that diverges from
#       lighthearted films like
#    4. I'm seeking a more serious and dramatic film recommendation
#
# ════════════════════════════════════════════════════════════════════════════════════
# [33] Dialogue 68038 – turn 4
#
# Context (last 2 lines):
#     Seeker: I'm really into movies with rich and multi-layered storylines, intense melodrama, and a serious tone. The characters' inner turmoil and epic showdowns always keep me captivated. Can you recommend something along those lines?
#     Recommender: Based on your preferences, I think you might enjoy "Follow the Fleet (1936)." It has a rich storyline, intense melodrama, and impressive musical numbers that might captivate you. The characters' inner turmoil and dramatic performances are central to the film's theme, which aligns with your preferences.
#
# Seeker turn:
#    I appreciate the recommendation, but I'm not quite in the mood for a musical
# film at the moment. I prefer movies with a more serious and dramatic tone,
# without the musical numbers. Do you have any other recommendations for me?
#
# Clarifications:
#    1. I'm not interested in watching a lighthearted, musical film; instead, I'd
#       like a serious and dramatic movie with no songs
#    2. I'm seeking a movie with a serious and dramatic tone, devoid of musical
#       numbers
#    3. I'm not in the mood for a light-hearted film; I prefer serious and dramatic
#       movies without musical elements
#    4. I'm not a fan of light-hearted films; I prefer movies with a serious and
#       dramatic tone, free from musical elements
#
# ════════════════════════════════════════════════════════════════════════════════════
# [34] Dialogue 60477 – turn 4
#
# Context (last 2 lines):
#     Seeker: I generally enjoy movies with captivating action scenes, strong writing and storyline, and a memorable soundtrack. The special effects and a satisfying conclusion are also important to me. The extended streaming cut version with added scenes is a plus as well. Any recommendations based on that?
#     Recommender: I think you might enjoy "Along Came Polly" (2004). It has entertaining action scenes, a well-written plot, and a satisfying conclusion. Plus, it's a comedy with a romantic twist, so I think it will appeal to you!
#
# Seeker turn:
#    "Along Came Polly" doesn't quite have the type of action scenes I'm looking
# for, and the genre is a bit different from what I usually go for. I'm more into
# movies with extraordinary and breathtaking action scenes, coupled with good
# ...
#    2. I enjoy suspenseful thrillers with well-paced narratives and memorable
#       character portrayals, and I value exceptional acting performances from
#       the cast
#    3. I enjoy suspenseful thrillers with good pacing and vivid characters, and
#       appreciate strong performances from the actors
#    4. Seeking suspenseful thrillers with great pacing and colorful characters, and
#       excellent performances from the cast, on Netflix
#
# ════════════════════════════════════════════════════════════════════════════════════
# [190] Dialogue 36342 – turn 6
#
# Context (last 2 lines):
#     Seeker: I appreciate your recommendation, but I have already watched "Courage Under Fire" and I was very disappointed with the script and the acting. The movie dragged on way too long, especially towards the end. Do you have any other recommendations?
#     Recommender: Based on your preference for strong performances and historical accuracy, I think you would really enjoy "The Doors." Val Kilmer's performance as Jim Morrison is exceptional, and the film features documentary footage of The Doors and their music. Plus, it captures the energy and enthusiasm of the band and their era.
#
# Seeker turn:
#    I'm sorry, but I have already watched "The Doors" and enjoyed Val Kilmer's
# portrayal of Jim Morrison, but I'm in the mood for something different. Can you
# recommend another movie?
#
# Clarifications:
#    1. I've seen a performance of Jim Morrison by Val Kilmer and now I'm looking
#       for a different perspective on a famous musician
#    2. Seeking a film about a rock band with a complex lead singer
#    3. I'm looking for a movie featuring prominent actors similar to Val Kilmer,
#       Tom Cruise, and Brad Pitt
#    4. I'm looking for a movie about an influential person, not Val Kilmer's
#       portrayal of Jim Morrison
#
# ════════════════════════════════════════════════════════════════════════════════════
# [191] Dialogue 25271 – turn 8
#
# Context (last 2 lines):
#     Seeker: I appreciate the recommendation, but I'm looking for something with a more contemporary setting and a bit more humor. "Gallipoli" seems like a well-made film, but it doesn't quite align with my preferences for this movie night. Do you have any other suggestions that may have the common features I mentioned earlier?
#     Recommender: How about "Ant-Man and the Wasp" (2018)? It has a contemporary setting, great visuals, an incredible cast, and plenty of genuinely funny moments. It also seamlessly fits into the larger Marvel universe if you're into that.
#
# Seeker turn:
#    "Ant-Man and the Wasp" seems to check off a lot of the boxes for me. The
# humor is great, and Paul Rudd and Michael Douglas play well off of each other.
# The visual effects are stunning, and the action is fast-paced. However, the
# plot's reliance on extensive knowledge of the Marvel universe and the straying
# into science fiction territory in the ending are aspects that I dislike. Can you
# recommend something else that may align more closely with the features I
# mentioned earlier?
#
# Clarifications:
#    1. The humor, acting, and visuals in the Marvel film are enjoyable, but the
#       reliance on prior knowledge and sci-fi elements detract from the
#       experience
#    2. The humor, performances, and visuals in impress me, but its science fiction
#       elements and reliance on prior Marvel knowledge detract from the
#       experience
#    3. The movie's humor, character interactions, and visual effects are strong,
#       but its sci-fi elements and reliance on prior Marvel knowledge detract
#       from my enjoyment
#    4. I enjoy the blend of humor, strong performances, and visual effects in films
#       like Ant-Man and the Wasp, but find their reliance on franchise
#       knowledge and sci-fi elements unappe
#
# ════════════════════════════════════════════════════════════════════════════════════
# [192] Dialogue 64479 – turn 4
#
# Context (last 2 lines):
#     Seeker: I'm generally into movies with beautiful stills and an artistic feel, interesting adventures of the main character, fitting music choice, and good acting.
#     Recommender: How about "Mr. Bean's Holiday"? It has beautiful visuals, a feel-good vibe, and Rowan Atkinson's performance is always a delight to watch. Plus, it's a family-friendly comedy with an interesting adventure of the main character.
#
# Seeker turn:
#    I appreciate the recommendation, but "Mr. Bean's Holiday" doesn't quite match
# my preference for fitting music choice and good acting. I tend to enjoy movies
# with comedic performances, entertaining storylines, and believable characters.
# Any other recommendations that come to mind based on these preferences?
#
# Clarifications:
#    1. I prefer movies with comedic performances, entertaining storylines, and
#       believable characters
#    2. I prefer movies with comedic performances, entertaining storylines, and
#       believable characters, making me question whether other films might
#       better suit my taste
#    3. I prefer comedies with quick-witted humor, engaging plots, and relatable
#       characters, offering entertainment without lengthy running times or
#       excessive complexity
#    4. I prefer movies with comedic performances, engaging storylines, and
#       authentic characters, which can provide an entertaining experience
#
# ════════════════════════════════════════════════════════════════════════════════════
# [193] Dialogue 56 – turn 6
#
# Context (last 2 lines):
#     Seeker: I appreciate the recommendation, but I have already seen "Swades" (2004) and, while it fits some of my preferences, it also lacks some common features of the movies I have enjoyed before. I'm looking for something with a bit more mystery and a touch of horror, as well as extraordinary direction. Any other recommendations?
#     Recommender: I recommend checking out "The Exorcist" (1973). It's a well-made and daring movie with exceptional acting and a captivating storyline. It also has a touch of mystery and horror, as well as extraordinary direction.
#
# Seeker turn:
#    I see where you're coming from, but "The Exorcist" (1973) has too much gore
# and nudity for my taste. I'm looking for something with a true horror classic
# feel, but without the excessive expletives and swearing. Do you have any other
# recommendations?
#
# Clarifications:
#    1. I'm seeking a classic horror film with a true horror feel, excluding
#       explicit content and excessive language
#    2. I'm seeking a classic horror film that captures the eerie atmosphere without
#       gratuitous violence, gore, or profanity
#    3. I'm seeking a classic horror film with an eerie atmosphere and intense
#       scares, minus excessive violence and strong language
#    4. I'm seeking a horror film that captures the classic atmosphere without
#       gratuitous violence or explicit content
#
# ════════════════════════════════════════════════════════════════════════════════════
# [194] Dialogue 16657 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I'm in the mood for something amusing and entertaining, with good
# storytelling and interesting characters. I enjoy movies that have strong themes
# and decent dialogue.
#
# Clarifications:
#    1. I'm drawn to movies with engaging stories, memorable characters, and
#       impactful themes, accompanied by well-crafted dialogue
#    2. I crave a movie with engaging storytelling, memorable characters, and
#       meaningful themes, accompanied by sharp dialogue
#    3. She has made a successful transition to adult roles, starring in films like
#       and showcasing her versatility as an actress
#    4. I'm seeking a film with engaging storytelling, relatable characters, and
#       meaningful themes, accompanied by effective dialogue
#
# ════════════════════════════════════════════════════════════════════════════════════
# [195] Dialogue 56828 – turn 6
#
# Context (last 2 lines):
#     Seeker: I'm not particularly fond of "X-Men: The Last Stand." While it does have good action sequences and some fine acting, I felt that the story was not as well developed and there were too many characters popping up. It seemed more like an eye candy treat than a thought-provoking movie. Do you have any other recommendations that are more in line with the movies I've enjoyed in the past?
#     Recommender: How about checking out "The American President"? It features strong performances and a unique spin on a romance storyline with political themes. It's quite thought-provoking and has a lot of depth to the characters and their vulnerabilities.
#
# Seeker turn:
#    I've actually watched "The American President" before, and while it does have
# some strong performances, I found the romance storyline to be a bit too
# predictable and cliché. I didn't feel it had the intellectual look at
# vulnerability and blurring of lines that I usually appreciate in movies. Do you
# have any other recommendations?
#
# Clarifications:
#    1. The romance storyline in felt overly predictable and lacked depth, failing
#       to explore themes of vulnerability and blurred lines
#    2. The movie's romance storyline felt predictable and clichéd, lacking depth
#       and nuance in its portrayal of vulnerability and blurred moral
#    3. I was disappointed with the predictable and clichéd romance storyline in ,
#       which didn't explore vulnerability and blurred boundaries as deeply as
#       I'd like
#    4. I was underwhelmed by the predictable and clichéd romance in , seeking more
#       nuanced explorations of vulnerability and blurred lines in other films
#
# ════════════════════════════════════════════════════════════════════════════════════
# [196] Dialogue 10412 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I like movies with strong dialogue and well-developed characters. I also
# enjoy thought-provoking plots and emotional depth. Any suggestions based on
# that?
#
# Clarifications:
#    1. I appreciate stories with engaging dialogue, memorable characters, and
#       meaningful storylines that evoke emotions
#    2. I appreciate movies with memorable dialogue, complex characters, and
#       intricate narratives that explore deeper themes and emotions
#    3. I crave stories with clever conversations, richly drawn characters, and
#       complex narratives that stir my emotions and intellect
#    4. I'm drawn to films featuring memorable dialogue, nuanced character
#       development, and intellectually stimulating narratives that evoke a
#       range of emotions
#
# ════════════════════════════════════════════════════════════════════════════════════
# [197] Dialogue 55678 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I'm generally into movies with a historical setting and unique
# cinematography. I also enjoy performances that stand out and fantasy/adventure
# elements. Any recommendations based on that?
#
# Clarifications:
#    1. I appreciate historical settings, exceptional cinematography, and
#       outstanding performances, often combined with fantasy and adventure
#       elements in films
#    2. I appreciate films that combine historical settings, distinctive visuals,
#       and exceptional acting, along with fantasy and adventure elements
#    3. I prefer movies with historical settings, distinctive camera work, and
#       outstanding acting, often combined with fantastical or adventurous
#       themes
#    4. I rephrase the seeker's message to: I appreciate movies with historical
#       settings, distinct cinematography, and outstanding performances,
#       especially those incorporating fantasy and adventure elements
#
# ════════════════════════════════════════════════════════════════════════════════════
# [198] Dialogue 17258 – turn 6
#
# Context (last 2 lines):
#     Seeker: Thanks for the recommendation! I actually prefer live-action movies over animation. I'm also more interested in a movie with a more mature storyline and character development. Any other recommendations that fit that description?
#     Recommender: How about "Music and Lyrics (2007)"? It has great acting, a mature storyline, and a good balance of drama and romance. Plus, the characters have well-written development and the movie has catchy music. I think it would be a great fit for what you're looking for.
#
# Seeker turn:
#    I appreciate the suggestion, but I'm not a big fan of romantic movies. I'm
# looking for something with a bit more action and intensity, along with a well-
# developed storyline and strong character development.
#
# Clarifications:
#    1. I prefer action-packed films with intense plots and well-written characters
#    2. I'm seeking an action-packed movie with a strong narrative and complex
#       characters
#    3. I prefer films that balance action and intensity with well-developed
#       storylines and characters, prioritizing strong narrative and character
#       development over romance
#    4. Action-packed stories with well-developed characters are essential to a
#       thrilling cinematic experience
#
# ════════════════════════════════════════════════════════════════════════════════════
# [199] Dialogue 46278 – turn 2
#
# Context (last 2 lines):
#     Seeker: Hi there! I'm in the mood to watch a movie. Can you recommend something?
#     Recommender: Absolutely! What kind of movie are you in the mood for? Any specific genre or theme?
#
# Seeker turn:
#    I'm looking for a movie with great acting and a well-structured storyline,
# like the ones that capture the essence of a book and have excellent casting of
# actors.
#
# Clarifications:
#    1. I seek a movie with outstanding performances and a well-plotted narrative
#       that effectively adapts the essence of its source material
#    2. A movie with exceptional performances and a narrative structure that
#       effectively translates a book's essence, featuring outstanding actor
#       casting
#    3. A movie with exceptional performances and a well-crafted narrative,
#       featuring talented actors who bring literary works to life on screen
#    4. A movie with exceptional performances and a coherent narrative, similar to
#       those that successfully adapt literary works, with remarkable actor
#       casting, and an old classic feel
#
# ════════════════════════════════════════════════════════════════════════════════════
# [200] Dialogue 12737 – turn 4
#
# Context (last 2 lines):
#     Seeker: I tend to enjoy movies with dystopian tones and thought-provoking moral questions. I also appreciate good special effects that enhance the story.
#     Recommender: I think you might enjoy "Papillon (2018)"! It has a compelling narrative with strong moral questions, and the special effects really enhance the story. Plus, it has an adventurous and dramatic tone that I think you'll appreciate.
#
# Seeker turn:
#    "Papillon (2018)" sounds interesting, but I'm looking for something with a
# bit more action and a twist of emotions and betrayal among the characters. Any
# recommendations that match that description?
#
# Clarifications:
#    1. A psychological thriller with complex characters and unexpected plot turns,
#       featuring individuals whose actions have a profound impact on one
#       another
#    2. A psychological thriller with complex relationships and surprising plot
#       turns would captivate me, featuring characters struggling with
#       secrets, lies, and moral dilemmas
#    3. The film you're seeking is a thrilling drama with action, emotional tension,
#       and character-driven plot twists involving deception and betrayal
#    4. A gripping thriller with intense action, emotional depth, and treacherous
#       character dynamics is needed, preferably with a complex plot featuring
#       deceitful relationships

# %% [markdown]
# Each ambiguos question ended up having between 1 and 8 valid clarifications.

# %% [markdown]
# # Generate Llama, Qwen and Deepseek answers to clarifications

# %% [markdown]
# Download clarifications.json file:

# %%
# !gdown 1dBZezglGe9_B6XzQOWiq5dzL1756QX8L
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1dBZezglGe9_B6XzQOWiq5dzL1756QX8L
# To: /content/clarifications.json
# 100% 261k/261k [00:00<00:00, 110MB/s]

# %% [markdown]
# Download models:

# %%
# !gdown 1msG3qe4ZQFwbc_GGeMIrjv2nvAOa24IJ
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1msG3qe4ZQFwbc_GGeMIrjv2nvAOa24IJ
# From (redirected): https://drive.google.com/uc?id=1msG3qe4ZQFwbc_GGeMIrjv2nvAOa24IJ&confirm=t&uuid=ba85cac3-6ab9-496c-939a-ce8e37fcc9bb
# To: /content/pearl_deepseek_model.zip
# 100% 158M/158M [00:02<00:00, 65.4MB/s]

# %%
# !gdown 1HERbin40CpFyAsq_8QtgJd6OdzOk6QXj
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1HERbin40CpFyAsq_8QtgJd6OdzOk6QXj
# From (redirected): https://drive.google.com/uc?id=1HERbin40CpFyAsq_8QtgJd6OdzOk6QXj&confirm=t&uuid=4c58d8ca-410e-4bcc-ad8f-5a4ac860e391
# To: /content/pearl_llama_model.zip
# 100% 92.5M/92.5M [00:01<00:00, 59.8MB/s]

# %%
# !gdown 1DqD4g0vT8SWggA8TQa4ryMMxALx8PAu4
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1DqD4g0vT8SWggA8TQa4ryMMxALx8PAu4
# From (redirected): https://drive.google.com/uc?id=1DqD4g0vT8SWggA8TQa4ryMMxALx8PAu4&confirm=t&uuid=f436c4d4-b065-4e4b-b983-baba41b1ab84
# To: /content/pearl_qwen_model.zip
# 100% 68.4M/68.4M [00:01<00:00, 56.9MB/s]

# %%
# !unzip -q pearl_deepseek_model.zip -d .
# !unzip -q pearl_llama_model.zip    -d .
# !unzip -q pearl_qwen_model.zip     -d .

# %%
import json, math, os, torch
from pathlib import Path
from tqdm.auto import tqdm
from unsloth import FastLanguageModel
from unsloth.chat_templates import get_chat_template
# Out:
# /tmp/ipython-input-15-1644933877.py:4: UserWarning: WARNING: Unsloth should be imported before transformers to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth import FastLanguageModel
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
DEVICE          = "cuda" if torch.cuda.is_available() else "cpu"
MAX_SEQ_LENGTH  = 2_048
GEN_BATCH_SIZE  = 8                 # prompts / batch
SOURCE_FILE     = "clarifications.json"

CHECKPOINTS = [
    ("qwen",     "pearl_qwen_model",     "qwen-2.5"),
    ("llama3",   "pearl_llama_model",    "llama-3.2"),
    ("deepseek", "pearl_deepseek_model", "llama-3.1"),
]

def load_unsloth(dir, template):
    m, tok = FastLanguageModel.from_pretrained(
        dir, max_seq_length=MAX_SEQ_LENGTH,
        dtype=None, load_in_4bit=True)
    FastLanguageModel.for_inference(m)
    tok = get_chat_template(tok, chat_template=template)
    return m, tok

def build_prompt(tok, user_msg):
    msgs = [
        {"role":"system",
         "content":"You are a helpful movie-recommender. Reply with 1-3 suggestions."},
        {"role":"user", "content":user_msg},
    ]
    return tok.apply_chat_template(msgs, tokenize=False, add_generation_prompt=True)

def batch_generate_once(model, tok, clarifications, *, do_sample=False):
    prompts = [build_prompt(tok, c) for c in clarifications]
    batch   = tok(prompts, return_tensors="pt", padding=True, truncation=False).to(DEVICE)

    gen_kwargs = dict(
        max_new_tokens          = 128,
        output_scores           = True,
        return_dict_in_generate = True,
        pad_token_id            = tok.eos_token_id,
        do_sample               = do_sample,
    )
    if do_sample:
        gen_kwargs.update(dict(temperature=0.8, top_p=0.95, top_k=50))

    with torch.no_grad():
        outs = model.generate(**batch, **gen_kwargs)

    seqs   = outs.sequences.cpu()   # (B, prompt+gen_len)
    scores = outs.scores            # list of length gen_len, each (B, V)

    prompt_len = batch["input_ids"].shape[1]

    eos_id = tok.eos_token_id
    pad_id = getattr(tok, "pad_token_id", eos_id)

    answers, total_logps = [], []
    for b in range(seqs.size(0)):
        # extract generated tokens
        gen_ids = seqs[b, prompt_len:].tolist()

        # trim everything from first EOS/PAD onward
        trimmed = []
        for tid in gen_ids:
            if tid in (eos_id, pad_id):
                break
            trimmed.append(tid)
        gen_ids = trimmed

        # handle empty generation after trimming
        if not gen_ids:
            answers.append("")
            total_logps.append(float("nan"))
            continue

        # sum log-probs only over real tokens
        s = 0.0
        for t, token_id in enumerate(gen_ids):
            if t >= len(scores):
                # shouldn't happen, but guard anyway
                break
            logits = scores[t][b]               # raw logits tensor, size V
            logp   = torch.log_softmax(logits, dim=-1)[token_id].item()
            s += logp

        # decode and record
        answers.append(tok.decode(gen_ids, skip_special_tokens=True).strip())
        total_logps.append(s)

    return answers, total_logps

# %% [markdown]
# Let's generate the clarification's answers.

# %%
# Load clarifications
clar_rows = []
with open(SOURCE_FILE, encoding="utf-8") as fh:
    for ln in fh:
        rec = json.loads(ln)
        for k, clar in enumerate(rec["clarifications"]):
            clar_rows.append({
                "dialogue_id": rec["dialogue_id"],
                "turn_id"    : rec["turn_id"],
                "clar_idx"   : k,
                "prompt"     : clar,
            })
print("Clarifications:", len(clar_rows))

# Generation loop per checkpoint
for tag, folder, template in CHECKPOINTS:
    print(f"\n=== {tag.upper()} ===")
    model, tok = load_unsloth(folder, template)
    out_path   = f"answers_{tag}_1shot.jsonl"

    with open(out_path, "w", encoding="utf-8") as fout:
        for i in tqdm(range(0, len(clar_rows), GEN_BATCH_SIZE),
                      desc=f"{tag}: batches"):
            batch_rows = clar_rows[i:i+GEN_BATCH_SIZE]
            answers, logps = batch_generate_once(model, tok, [r["prompt"] for r in batch_rows], do_sample = True)

            for rec, ans, lp in zip(batch_rows, answers, logps):
                fout.write(json.dumps({**rec,
                                       "answer": ans,
                                       "logprob": lp},
                                      ensure_ascii=False) + "\n")
    print("↳ saved", out_path)

print("\nFinished – one answer (with log-prob) for every clarification.")
# Out:
# Clarifications: 799
#
# === QWEN ===
# ==((====))==  Unsloth 2025.6.12: Fast Qwen3 patching. Transformers: 4.53.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/1.41G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# Unsloth 2025.6.12 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.
# qwen: batches:   0%|          | 0/100 [00:00<?, ?it/s]
# Qwen3ForCausalLM has no `_prepare_4d_causal_attention_mask_with_cache_position` method defined in its base modeling class. Compiled forward passes will be sub-optimal. If you're writing code, see Llama for an example implementation. If you're a user, please report this issue on GitHub.
# ↳ saved answers_qwen_1shot.jsonl
#
# === LLAMA3 ===
# ==((====))==  Unsloth 2025.6.12: Fast Llama patching. Transformers: 4.53.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.35G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# llama3: batches:   0%|          | 0/100 [00:00<?, ?it/s]
# LlamaForCausalLM has no `_prepare_4d_causal_attention_mask_with_cache_position` method defined in its base modeling class. Compiled forward passes will be sub-optimal. If you're writing code, see Llama for an example implementation. If you're a user, please report this issue on GitHub.
# ↳ saved answers_llama3_1shot.jsonl
#
# === DEEPSEEK ===
# ==((====))==  Unsloth 2025.6.12: Fast Llama patching. Transformers: 4.53.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# Unsloth 2025.6.12 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# deepseek: batches:   0%|          | 0/100 [00:00<?, ?it/s]
# ↳ saved answers_deepseek_1shot.jsonl
#
# Finished – one answer (with log-prob) for every clarification.

# %% [markdown]
# # Metrics

# %% [markdown]
# You can download pregenerated answers to clarifications using:

# %%
# !gdown 1fdoRFUzywPEJlJa6hTmVn16xSOMU0dxW
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1fdoRFUzywPEJlJa6hTmVn16xSOMU0dxW
# To: /content/answers_deepseek_1shot.jsonl
# 100% 358k/358k [00:00<00:00, 113MB/s]

# %%
# !gdown 1gOqIPws8zYGCgwLDT4t9IEb5KZzDbtvg
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gOqIPws8zYGCgwLDT4t9IEb5KZzDbtvg
# To: /content/answers_llama3_1shot.jsonl
# 100% 406k/406k [00:00<00:00, 131MB/s]

# %%
# !gdown 1q4suiN1I1fRpYCfa1Ts-VEfHfmq5oc2A
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1q4suiN1I1fRpYCfa1Ts-VEfHfmq5oc2A
# To: /content/answers_qwen_1shot.jsonl
# 100% 324k/324k [00:00<00:00, 123MB/s]

# %% [markdown]
# Film extractor:

# %%
# final_uncertainty_metrics.py  ── run in a Colab cell
import json, math, statistics, re, collections, pathlib, csv, math
from statistics import fmean, median

# ───────── files to evaluate ─────────
FILES = {
    "llama3"  : "answers_llama3_1shot.jsonl",
    "deepseek": "answers_deepseek_1shot.jsonl",
    "qwen"    : "answers_qwen_1shot.jsonl",
}

# ───────── regex to pull movie titles ─────────
TITLE_RE = re.compile(
    r'''
      "([^"]+?)"\s*\(\d{4}\)      |  # "The Sixth Sense (1999)"
      "([^"]+?)"\s*               |  # "The Dark Knight"   (no year)
      ([^"]+?)\s*\(\d{4}\)           #  The Shallows (2016)  ← no quotes
    ''',
    re.VERBOSE,
)

LIST_PREFIX = re.compile(r'^\s*(?:[-–●]|[0-9]{1,2}\.|Based on:)\s*', re.I)
YEAR_SUFFIX = re.compile(r'\s*\(\d{4}\)\s*$', re.I)

def post_clean(title: str) -> str:
    """Quita guiones, numeraciones o el año pegado al final."""
    title = LIST_PREFIX.sub('', title)
    title = YEAR_SUFFIX.sub('', title)      # (1999)  al final
    return title.strip()

def extract_title(text: str) -> str | None:
    m = TITLE_RE.search(text)
    if not m:
        return None
    raw = next(g for g in m.groups() if g)
    return post_clean(raw) or None


def entropy(lst):
    """Shannon entropy in bits."""
    if len(lst) < 2:
        return 0.0
    c, n = collections.Counter(lst), len(lst)
    return -sum((v/n)*math.log2(v/n) for v in c.values())

# Collect per-turn data
per_model_data = {}          # tag  { (dlg,turn): {"titles":[...], "logp":[...] } }

# For each model
for tag, path in FILES.items():
    print(tag)
    turn_dict = collections.defaultdict(lambda: {"titles": [], "logp": []})

    with open(path, encoding="utf-8") as fh:
        for raw in fh:
            line = raw.strip()
            if not line:
                continue                        # skip blank lines
            try:
                rec = json.loads(line)
            except json.JSONDecodeError:
                print(f"⚠️  bad JSON row skipped in {path}")
                continue


            key = (rec["dialogue_id"], rec["turn_id"])

            # ─ titles ─
            title = extract_title(rec.get("answer", ""))
            # print("Title: ", title)
            if title:
                turn_dict[key]["titles"].append(title)

            # ─ log-probs ─
            lp = rec.get("logprob", float("-inf"))
            if math.isfinite(lp):
                turn_dict[key]["logp"].append(lp)

    per_model_data[tag] = turn_dict

# compute metrics ─────────
csv_rows = []
for tag, turns in per_model_data.items():
    alea_vals, epi_vals = [], []

    for (dlg, tid), info in turns.items():
        titles, logps = info["titles"], info["logp"]

        alea = entropy(titles)                     # proxy-aleatoric
        epi  = -fmean(logps) if logps else float("nan")   # proxy-epistemic

        alea_vals.append(alea)
        epi_vals .append(epi)

        csv_rows.append([tag, dlg, tid,
                         len(titles), f"{alea:.4f}",
                         len(logps),  f"{epi:.4f}"])

    def safe_mean(xs):   return fmean(xs) if xs else float('nan')
    def safe_median(xs): return median(xs) if xs else float('nan')

    print(f"\n=== {tag.upper()} ===")
    print(f"Turns processed                  : {len(turns)}")
    print(f"Avg aleatoric entropy  (titles)  : {safe_mean(alea_vals):.3f}")
    print(f"Median aleatoric entropy         : {safe_median(alea_vals):.3f}")
    print(f"Avg epistemic uncertainty (−lp)  : {safe_mean(epi_vals):.3f}")
    print(f"Median epistemic uncertainty     : {safe_median(epi_vals):.3f}")

with open("uncertainty_summary.csv", "w", newline="", encoding="utf-8") as out:
    w = csv.writer(out)
    w.writerow(["model", "dialogue_id", "turn_id",
                "n_titles", "aleatoric_entropy",
                "n_logp", "avg_neg_logprob"])
    w.writerows(csv_rows)

print("\nPer-turn details written → uncertainty_summary.csv")
# Out:
# llama3
# deepseek
# qwen
# ⚠️  bad JSON row skipped in answers_qwen_1shot.jsonl
#
# === LLAMA3 ===
# Turns processed                  : 200
# Avg aleatoric entropy  (titles)  : 1.858
# Median aleatoric entropy         : 2.000
# Avg epistemic uncertainty (−lp)  : 46.376
# Median epistemic uncertainty     : 45.271
#
# === DEEPSEEK ===
# Turns processed                  : 200
# Avg aleatoric entropy  (titles)  : 0.384
# Median aleatoric entropy         : 0.000
# Avg epistemic uncertainty (−lp)  : 106.868
# Median epistemic uncertainty     : 105.773
#
# === QWEN ===
# Turns processed                  : 191
# Avg aleatoric entropy  (titles)  : 0.764
# Median aleatoric entropy         : 1.000
# Avg epistemic uncertainty (−lp)  : 29.090
# Median epistemic uncertainty     : 27.315
#
# Per-turn details written → uncertainty_summary.csv
